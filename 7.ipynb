# %%
import pandas as pd
import datetime as dt
df = pd.read_csv("amazon_review.csv")
df.head()
# Out:
#        reviewerID        asin  reviewerName helpful  \
# 0  A3SBTW3WS4IQSN  B007WTAJTO           NaN  [0, 0]
# 1  A18K1ODH1I2MVB  B007WTAJTO          0mie  [0, 0]
# 2  A2FII3I2MBMUIA  B007WTAJTO           1K3  [0, 0]
# 3   A3H99DFEG68SR  B007WTAJTO           1m2  [0, 0]
# 4  A375ZM4U047O79  B007WTAJTO  2&amp;1/2Men  [0, 0]
#
#                                           reviewText  overall  \
# 0                                         No issues.      4.0
# 1  Purchased this for my device, it worked as adv...      5.0
# 2  it works as expected. I should have sprung for...      4.0
# 3  This think has worked out great.Had a diff. br...      5.0
# 4  Bought it with Retail Packaging, arrived legit...      5.0
#
#                                   summary  unixReviewTime  reviewTime  \
# 0                              Four Stars      1406073600  2014-07-23
# 1                           MOAR SPACE!!!      1382659200  2013-10-25
# ...

# %%
pd.to_datetime(df["unixReviewTime"],unit="s").dt.date
# Out:
# 0       2014-07-23
# 1       2013-10-25
# 2       2012-12-23
# 3       2013-11-21
# 4       2013-07-13
#            ...
# 4910    2013-07-23
# 4911    2013-08-22
# 4912    2014-03-31
# 4913    2013-09-16
# 4914    2014-01-02
# Name: unixReviewTime, Length: 4915, dtype: object

# %%
df["reviewTime"] = df["reviewTime"].apply(pd.to_datetime)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4915 entries, 0 to 4914
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reviewerID      4915 non-null   object
#  1   asin            4915 non-null   object
#  2   reviewerName    4914 non-null   object
#  3   helpful         4915 non-null   object
#  4   reviewText      4914 non-null   object
#  5   overall         4915 non-null   float64
#  6   summary         4915 non-null   object
#  7   unixReviewTime  4915 non-null   int64
#  8   reviewTime      4915 non-null   datetime64[ns]
#  9   day_diff        4915 non-null   int64
#  10  helpful_yes     4915 non-null   int64
#  11  total_vote      4915 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(6)
# memory usage: 460.9+ KB

# %%
df["helpful_no"] = df["total_vote"] - df["helpful_yes"]

# %%
df.head()
# Out:
#        reviewerID        asin  reviewerName helpful  \
# 0  A3SBTW3WS4IQSN  B007WTAJTO           NaN  [0, 0]
# 1  A18K1ODH1I2MVB  B007WTAJTO          0mie  [0, 0]
# 2  A2FII3I2MBMUIA  B007WTAJTO           1K3  [0, 0]
# 3   A3H99DFEG68SR  B007WTAJTO           1m2  [0, 0]
# 4  A375ZM4U047O79  B007WTAJTO  2&amp;1/2Men  [0, 0]
#
#                                           reviewText  overall  \
# 0                                         No issues.      4.0
# 1  Purchased this for my device, it worked as adv...      5.0
# 2  it works as expected. I should have sprung for...      4.0
# 3  This think has worked out great.Had a diff. br...      5.0
# 4  Bought it with Retail Packaging, arrived legit...      5.0
#
#                                   summary  unixReviewTime reviewTime  \
# 0                              Four Stars      1406073600 2014-07-23
# 1                           MOAR SPACE!!!      1382659200 2013-10-25
# ...

# %%
df["overall"].mean()
# Out:
# 4.587589013224822

# %%
(df["reviewTime"].max() - df["reviewTime"]).dt.days
# Out:
# 0       137
# 1       408
# 2       714
# 3       381
# 4       512
#        ...
# 4910    502
# 4911    472
# 4912    251
# 4913    447
# 4914    309
# Name: reviewTime, Length: 4915, dtype: int64

# %%
df["day_diff"].max()
# Out:
# 1064

# %%
df.loc[df["day_diff"]<=30,"overall"].mean()
# Out:
# 4.742424242424242

# %%
df.loc[df["day_diff"]<=30,"overall"].mean() * 30/100 + \
    df.loc[(df["day_diff"]>30) & (df["day_diff"]<=90),"overall"].mean() * 27/100 + \
    df.loc[(df["day_diff"]>90) & (df["day_diff"]<=180),"overall"].mean() * 23/100 + \
    df.loc[(df["day_diff"]>180,"overall")].mean() *20/100
# Out:
# 4.703633775163116

# %%
df.head()
# Out:
#        reviewerID        asin  reviewerName helpful  \
# 0  A3SBTW3WS4IQSN  B007WTAJTO           NaN  [0, 0]
# 1  A18K1ODH1I2MVB  B007WTAJTO          0mie  [0, 0]
# 2  A2FII3I2MBMUIA  B007WTAJTO           1K3  [0, 0]
# 3   A3H99DFEG68SR  B007WTAJTO           1m2  [0, 0]
# 4  A375ZM4U047O79  B007WTAJTO  2&amp;1/2Men  [0, 0]
#
#                                           reviewText  overall  \
# 0                                         No issues.      4.0
# 1  Purchased this for my device, it worked as adv...      5.0
# 2  it works as expected. I should have sprung for...      4.0
# 3  This think has worked out great.Had a diff. br...      5.0
# 4  Bought it with Retail Packaging, arrived legit...      5.0
#
#                                   summary  unixReviewTime reviewTime  \
# 0                              Four Stars      1406073600 2014-07-23
# 1                           MOAR SPACE!!!      1382659200 2013-10-25
# ...

# %%
df["helpful_yes"].max()
# Out:
# 1952

# %%
import scipy.stats as st
import math
def wilson_lower_bound(up, down, confidence=0.95):

    n = up + down
    if n == 0:
        return 0
    z = st.norm.ppf(1 - (1 - confidence) / 2)
    phat = 1.0 * up / n
    return (phat + z * z / (2 * n) - z * math.sqrt((phat * (1 - phat) + z * z / (4 * n)) / n)) / (1 + z * z / n)

# %%
df["wlb"] =df.apply(lambda x:wilson_lower_bound(x["helpful_yes"],x["helpful_no"]),axis=1)
df.sort_values(by="wlb",ascending=False).head()
# Out:
#           reviewerID        asin             reviewerName       helpful  \
# 2031  A12B7ZMXFI6IXY  B007WTAJTO     Hyoun Kim "Faluzure"  [1952, 2020]
# 3449   AOEAD7DPLZE53  B007WTAJTO        NLee the Engineer  [1428, 1505]
# 4212   AVBMZZAFEKO58  B007WTAJTO              SkincareCEO  [1568, 1694]
# 317   A1ZQAQFYSXL5MQ  B007WTAJTO  Amazon Customer "Kelly"    [422, 495]
# 4672  A2DKQQIZ793AV5  B007WTAJTO                  Twister      [45, 49]
#
#                                              reviewText  overall  \
# 2031  [[ UPDATE - 6/19/2014 ]]So my lovely wife boug...      5.0
# 3449  I have tested dozens of SDHC and micro-SDHC ca...      5.0
# 4212  NOTE:  please read the last update (scroll to ...      1.0
# 317   If your card gets hot enough to be painful, it...      1.0
# 4672  Sandisk announcement of the first 128GB micro ...      5.0
#
#                                                 summary  unixReviewTime  \
# ...
